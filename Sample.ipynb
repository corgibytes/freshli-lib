// %%
#!pwsh
ls
// Out:
// <script type="text/javascript">#!javascript
// if ((typeof(requirejs) !==  typeof(Function)) || (typeof(requirejs.config) !== typeof(Function))) {
//     let script = document.createElement("script");
//     script.setAttribute("src", "https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js");
//     script.onload = function(){
//         loadDotnetInteractiveApi();
//     };
//     document.getElementsByTagName("head")[0].appendChild(script);
// }
// else {
//     loadDotnetInteractiveApi();
// }
//
// function loadDotnetInteractiveApi(){
//     let apiRequire = requirejs.config({context:"dotnet-interactive.83934.61239",paths:{dotnetInteractive:"http://localhost:61239/resources/dotnet-interactive"}});
//     apiRequire(['dotnetInteractive'],
//     function(api) {
//         api.createDotnetInteractiveClient("http://localhost:61239/", window);
//     },
//     function(error){
//         console.log(error);
//     });
// }</script>
// CODE_OF_CONDUCT.md
// Freshli
// ...

// %%
#!pwsh
#!time
dotnet build
dotnet pack
Get-ChildItem -Recurse *.nupkg
// Out:
// Microsoft (R) Build Engine version 16.6.0+5ff7b0c9e for .NET Core
// Copyright (C) Microsoft Corporation. All rights reserved.
//
//   Determining projects to restore...
//   All projects are up-to-date for restore.
//   Freshli -> /Users/mscottford/src/corgibytes/freshli/Freshli/bin/Debug/netcoreapp3.1/Freshli.dll
//   Freshli.Test -> /Users/mscottford/src/corgibytes/freshli/Freshli.Test/bin/Debug/netcoreapp3.1/Freshli.Test.dll
//   Archive:  nokotest.zip
//     inflating: nokotest/Gemfile
//     inflating: nokotest/Gemfile.lock
//     inflating: nokotest/.git/config
//    extracting: nokotest/.git/objects/0d/8f4f864a22eac5f72153cf1d77fc9791796e6d
//    extracting: nokotest/.git/objects/93/e24fec7e2d55e1f2649989a131b1a044008e60
//    extracting: nokotest/.git/objects/bb/e94adc863a728d5c63b1293a7d1d81ac437f30
//    extracting: nokotest/.git/objects/6e/dae1c2dc746439f567894cf77effc7a8abf97b
//    extracting: nokotest/.git/objects/01/7031627f36deb582d69cddd381718be0044b02
// ...

// %%
#i nuget:/Users/mscottford/src/corgibytes/freshli/Freshli/bin/Debug;/Users/mscottford/src/corgibytes/XPlot/pkg
#r nuget:freshli,1.0.0-dev
#r nuget:XPlot.Plotly,3.1.0-preview1-preview-LocalBuild
// Out:
// <script type="text/javascript">#!javascript
// if ((typeof(requirejs) !==  typeof(Function)) || (typeof(requirejs.config) !== typeof(Function))) {
//     let script = document.createElement("script");
//     script.setAttribute("src", "https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js");
//     script.onload = function(){
//         loadDotnetInteractiveApi();
//     };
//     document.getElementsByTagName("head")[0].appendChild(script);
// }
// else {
//     loadDotnetInteractiveApi();
// }
//
// function loadDotnetInteractiveApi(){
//     let apiRequire = requirejs.config({context:"dotnet-interactive.31941.64160",paths:{dotnetInteractive:"http://localhost:64160/resources/dotnet-interactive"}});
//     apiRequire(['dotnetInteractive'],
//     function(api) {
//         api.createDotnetInteractiveClient("http://localhost:64160/", window);
//     },
//     function(error){
//         console.log(error);
//     });
// }</script>
// ...

// %%
using XPlot.Plotly;

using Freshli;
using Freshli.Languages.Ruby;
using Freshli.Languages.Php;
using Freshli.Languages.Python;

ManifestFinder.Register<RubyBundlerManifestFinder>();
ManifestFinder.Register<PhpComposerManifestFinder>();
ManifestFinder.Register<PipRequirementsTxtManifestFinder>();

FileHistoryFinder.Register<GitFileHistoryFinder>();

var runner = new Runner();

// %%
var projects = new Dictionary<string, IList<MetricsResult>>();
projects["pyspider"] = runner.Run("https://github.com/binux/pyspider");
projects["glances"] = runner.Run("https://github.com/nicolargo/glances");


var series = projects.Select(p => new Graph.Scattergl { 
  name = p.Key, 
  x = p.Value.Select(r => r.Date),
  y = p.Value.Select(r => r.LibYear.Total)
});


var chart = Chart.Plot(series.ToArray());
chart.WithTitle("LibYear over time");
display(chart)
// Out:
// <div id="70d5f139-31a1-45a7-ac2f-c52357ef1a77" style="width: 900px; height: 500px;"></div>
// <script type="text/javascript">
//
// var renderPlotly = function() {
//     var xplotRequire = requirejs.config({context:'xplot-3.0.1',paths:{plotly:'https://cdn.plot.ly/plotly-1.49.2.min'}});
//     xplotRequire(['plotly'], function(Plotly) {
//
// ...

// %%
var project = runner.Run("https://github.com/binux/pyspider");
var names = project.Select(r => r.LibYear.Select(p => p.Name));

// %%
var dates = project.Select(r => r.Date);

// %%
var totalLibYears = project.Select(r => r.LibYear.Total);

// %%
var names = project.Select(r => r.LibYear.Select(p => p.Name).ToArray()).Aggregate(
    new HashSet<string>(), 
    (hash, values) => {
        foreach(var value in values) {
            hash.Add(value);
        }
        return hash;
    }
);
names
// Out:
// <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td>Flask</td></tr><tr><td>1</td><td>Jinja2</td></tr><tr><td>2</td><td>MarkupSafe</td></tr><tr><td>3</td><td>Werkzeug</td></tr><tr><td>4</td><td>backports.ssl-match-hostname</td></tr><tr><td>5</td><td>chardet</td></tr><tr><td>6</td><td>cssselect</td></tr><tr><td>7</td><td>itsdangerous</td></tr><tr><td>8</td><td>lxml</td></tr><tr><td>9</td><td>pycurl</td></tr><tr><td>10</td><td>pyquery</td></tr><tr><td>11</td><td>requests</td></tr><tr><td>12</td><td>tornado</td></tr><tr><td>13</td><td>mysql-connector-python</td></tr><tr><td>14</td><td>pika</td></tr><tr><td>15</td><td>pymongo</td></tr><tr><td>16</td><td>unittest2</td></tr><tr><td>17</td><td>Flask-Login</td></tr><tr><td>18</td><td>u-msgpack-python</td></tr><tr><td>19</td><td>click</td></tr><tr><td colspan="2">(more...)</td></tr></tbody></table>

// %%
var areaSeries = new List<Graph.Scattergl>();

foreach (var name  in names) {
    areaSeries.Add(new Graph.Scattergl {
        name = name,
        x = project.Select(r => r.Date),
        y = project.Where(r => r.LibYear.Any(p => p.Name == name)).Select(r => r.LibYear[name].Value)
    });
}

var chart = Chart.Plot(areaSeries.ToArray());
chart.WithTitle("LibYear over time per dependency");
display(chart)
// Out:
// <div id="ec9fd2c0-b1fa-4534-b99c-4910ab51be1a" style="width: 900px; height: 500px;"></div>
// <script type="text/javascript">
//
// var renderPlotly = function() {
//     var xplotRequire = requirejs.config({context:'xplot-3.0.1',paths:{plotly:'https://cdn.plot.ly/plotly-1.49.2.min'}});
//     xplotRequire(['plotly'], function(Plotly) {
//
// ...

// %%
var areaSeries = new List<Graph.Scatter>();

foreach (var name  in names) {
    areaSeries.Add(new Graph.Scatter {
        name = name,
        x = project.Select(r => r.Date),
        y = project.Where(r => r.LibYear.Any(p => p.Name == name)).Select(r => r.LibYear[name].Value),
        fill = "tonexty"
    });
}

var chart = Chart.Plot(areaSeries.ToArray());
chart.WithTitle("LibYear over time per dependency");
display(chart)
// Out:
// <div id="5184780f-9b8f-4927-bfcc-ce6e2d842f2e" style="width: 900px; height: 500px;"></div>
// <script type="text/javascript">
//
// var renderPlotly = function() {
//     var xplotRequire = requirejs.config({context:'xplot-3.0.1',paths:{plotly:'https://cdn.plot.ly/plotly-1.49.2.min'}});
//     xplotRequire(['plotly'], function(Plotly) {
//
// ...

// %%
var areaSeries = new List<Graph.Scatter>();

foreach (var name  in names) {
    areaSeries.Add(new Graph.Scatter {
        name = name,
        x = project.Select(r => r.Date),
        y = project.Where(r => r.LibYear.Any(p => p.Name == name)).Select(r => r.LibYear[name].Value),
        fill = "tonexty",
        stackgroup = "one"
    });
}

var chart = Chart.Plot(areaSeries.ToArray());
chart.WithTitle("LibYear over time per dependency");
display(chart)
// Out:
// (10,9): error CS0117: 'Graph.Scatter' does not contain a definition for 'stackgroup'

// %%
typeof(Graph.Scatter).Assembly.ToString()
// Out:
// XPlot.Plotly, Version=1.0.0.0, Culture=neutral, PublicKeyToken=null

// %%
new Graph.Scatter { stackgroup = "test" }
// Out:
// (1,21): error CS0117: 'Graph.Scatter' does not contain a definition for 'stackgroup'
